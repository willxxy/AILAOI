# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('drive/MyDrive/pests.ai AILAOI')

# %%
file_path = 'Data/Copy of Inspected_GSOB_Trees_0.csv'

# %%
df = pd.read_csv(file_path)

# %%
print(df.shape)
# Out:
# (7713, 29)

# %%
df.head()
# Out:
#    OBJECTID Current Status                   Date         Species  Height  \
# 0         1        Monitor    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 1         2  Removed Owner  10/17/2017 3:00:00 PM  Quer Agrifolia       0
# 2         3   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 3         4   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 4         5   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
#
#    Canopy Spread L  Canopy Spread W  Canopy Cover Staining  \
# 0                0                0             0      NaN
# 1                0                0             0      NaN
# 2                0                0             0      NaN
# 3                0                0             0      NaN
# 4                0                0             0      NaN
#
#    Diameter Breast Height  ...          created_date  \
# 0                      14  ...  3/19/2022 3:32:49 AM
# 1                      12  ...  3/19/2022 3:32:49 AM
# 2                       0  ...  3/19/2022 3:32:49 AM
# 3                      17  ...  3/19/2022 3:32:49 AM
# 4                      20  ...  3/19/2022 3:32:49 AM
#
#             last_edited_user      last_edited_date  OBJECTID_3  \
# 0  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM           1
# 1  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM           2
# 2  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM           3
# 3  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM           4
# 4  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM           5
#
#                                GlobalID Date Treated  Date TO BE Treated  \
# 0  5de2f1f9-dfc8-4db3-86d7-83be624c1285          NaN                 NaN
# 1  784313e1-dade-4b34-a377-51e25a485585          NaN                 NaN
# 2  332d5025-8602-473d-a388-4268b9bc7b26          NaN                 NaN
# 3  8e6a7e0d-a4bc-4485-86ec-efdd4c523efb          NaN                 NaN
# 4  20c48262-5e30-4c5a-b918-437aae8b92cd          NaN                 NaN
#
#    D Holes AFTER Treatment           x          y
# 0                      NaN -118.417815  34.617676
# 1                      NaN -118.417185  34.617986
# 2                      NaN -118.417338  34.618055
# 3                      NaN -118.417169  34.618023
# 4                      NaN -118.417205  34.618024
#
# [5 rows x 29 columns]

# %%
# randomly select half data
df = df.sample(frac = 0.5)

# %%
print(len(df))
# Out:
# 3856

# %%
# make a column to distribution
left = -118.96416666666667
right = -118.57805555555555
top = 34.117222222222225
bottom = 34.06666666666667

xr = np.random.uniform(left, right, len(df))
yr = np.random.uniform(top, bottom, len(df))

# %%
df['x'] = xr
df['y'] = yr
print(df.shape)
# Out:
# (3856, 29)

# %%
df.head()
# Out:
#       OBJECTID    Current Status                   Date         Species  \
# 1312      1314           Monitor   2/14/2017 4:00:00 PM  Quer Agrifolia
# 2689      2692      Non-Infested   9/20/2019 9:26:42 PM  Quer Agrifolia
# 6683      6697  Mark for Removal  11/18/2019 9:38:39 PM  Quer Agrifolia
# 5916      5922      Removed Fire   10/6/2017 3:00:00 PM  Quer Agrifolia
# 3326      3329      Removed Fire  10/30/2017 3:00:00 PM  Quer Agrifolia
#
#       Height  Canopy Spread L  Canopy Spread W  Canopy Cover Staining  \
# 1312      25                0                0            20      Yes
# 2689      40               15               20            40       No
# 6683      25               18               10            15      Yes
# 5916      25                0                0            25      Yes
# 3326      36                0                0            20      NaN
#
#       Diameter Breast Height  ...          created_date  \
# 1312                      14  ...  3/19/2022 3:32:49 AM
# 2689                      20  ...  3/19/2022 3:32:49 AM
# 6683                      11  ...  3/19/2022 3:32:49 AM
# 5916                      14  ...  3/19/2022 3:32:49 AM
# 3326                       0  ...  3/19/2022 3:32:49 AM
#
#                last_edited_user      last_edited_date  OBJECTID_3  \
# 1312  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM        1557
# 2689  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM        3139
# 6683  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM           0
# 5916  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM        6372
# 3326  Lady_Terrazas_LearnArcGIS  3/19/2022 3:32:49 AM        3776
#
#                                   GlobalID Date Treated  Date TO BE Treated  \
# 1312  2d2bc615-cc1e-4ba5-b214-d45888ef5f5c          NaN                 NaN
# 2689  8d23c913-a459-4c3b-8a3f-073cfd6a4b73          NaN                 NaN
# 6683  dc971839-f1e7-4121-84bc-b5e9df788cf7          NaN                 NaN
# 5916  1c289dc3-b7fb-4432-a3b1-b2047488dd7f          NaN                 NaN
# 3326  5e249644-ee14-424b-8f32-dfd230d74fa3          NaN                 NaN
#
#       D Holes AFTER Treatment           x          y
# 1312                      NaN -118.928314  34.080243
# 2689                      NaN -118.657137  34.098574
# 6683                      NaN -118.728087  34.067870
# 5916                      NaN -118.739613  34.112613
# 3326                      NaN -118.777997  34.089972
#
# [5 rows x 29 columns]

# %%
df = df.sample(100)

# %%
df
print(df.shape)
# Out:
# (100, 29)

# %%
df.to_csv('mock_data2.csv')
