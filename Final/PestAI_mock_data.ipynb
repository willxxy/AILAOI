# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# os.chdir('drive/MyDrive/pests.ai AILAOI')

# %%
file_path = 'Data/Inspected_GSOB_Trees_0.csv'

# %%
df = pd.read_csv(file_path)

# %%
print(df.shape)
# Out:
# (7713, 29)

# %%
df.head()
# Out:
#    OBJECTID Current Status                   Date         Species  Height  \
# 0         1        Monitor    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 1         2  Removed Owner  10/17/2017 3:00:00 PM  Quer Agrifolia       0
# 2         3   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 3         4   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 4         5   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
#
#    Canopy Spread L  Canopy Spread W  Canopy Cover Staining  \
# 0                0                0             0      NaN
# 1                0                0             0      NaN
# 2                0                0             0      NaN
# 3                0                0             0      NaN
# 4                0                0             0      NaN
#
#    Diameter Breast Height  ...          created_date  \
# 0                      14  ...  3/19/2022 3:32:49 AM
# 1                      12  ...  3/19/2022 3:32:49 AM
# ...

# %%
# randomly select half data
df = df.sample(frac = 0.5)
# df = df.sample(frac = 0.1)

# %%
print(len(df))
# Out:
# 3856

# %%
# make a column to distribution
left = -118.96416666666667
right = -118.57805555555555
top = 34.117222222222225
bottom = 34.06666666666667

xr = np.random.uniform(left, right, len(df))
yr = np.random.uniform(top, bottom, len(df))

# %%
df['x'] = xr
df['y'] = yr
print(df.shape)
# Out:
# (3856, 29)

# %%
df.head()
# Out:
#       OBJECTID Current Status                   Date         Species  Height  \
# 6306      6314   Non-Infested  10/16/2017 3:00:00 PM  Quer Agrifolia      18
# 1435      1437   Non-Infested   2/15/2017 4:00:00 PM  Quer Agrifolia      16
# 6186      6193   Non-Infested  11/13/2017 4:00:00 PM  Quer Agrifolia      35
# 710        712   Non-Infested  12/28/2016 4:00:00 PM  Quer Agrifolia      21
# 6861      6875        Monitor  12/11/2019 9:22:06 PM  Quer Agrifolia      35
#
#       Canopy Spread L  Canopy Spread W  Canopy Cover Staining  \
# 6306                0                0            10       No
# 1435                0                0            45       No
# 6186               35               35            25       No
# 710                 0                0            70      NaN
# 6861               20               20            50      Yes
#
#       Diameter Breast Height  ...          created_date  \
# 6306                      11  ...  3/19/2022 3:32:49 AM
# ...

# %%
# df = df.sample(100)

# %%
df
print(df.shape)
# Out:
# (3856, 29)

# %%
df.to_csv('mock_data.csv')
