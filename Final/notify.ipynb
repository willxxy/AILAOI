# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('drive/MyDrive/pests.ai AILAOI')

# %%
df = pd.read_csv('Data/Inspected_GSOB_Trees_0.csv')

# %%
df
# Out:
#       OBJECTID Current Status                   Date         Species  Height  \
# 0            1        Monitor    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 1            2  Removed Owner  10/17/2017 3:00:00 PM  Quer Agrifolia       0
# 2            3   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 3            4   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# 4            5   Removed Fire    1/2/2016 4:00:00 PM  Quer Agrifolia       0
# ...        ...            ...                    ...             ...     ...
# 7708      7722     Contract 4   2/24/2020 8:10:35 PM  Quer Agrifolia      45
# 7709      7723     Contract 4   2/24/2020 8:10:35 PM  Quer Agrifolia      45
# 7710      7724     Contract 4   2/24/2020 8:10:35 PM  Quer Agrifolia      45
# 7711      7725     Contract 4   2/24/2020 8:10:35 PM  Quer Agrifolia      45
# 7712      7726        Monitor   2/24/2020 8:10:35 PM  Quer Agrifolia      45
#
# ...

# %%
import smtplib, ssl

def notifiy(message):
    l = []
    
    port = 587  # For starttls
    smtp_server = "smtp.gmail.com"
    sender_email = "yanhaoshen97@gmail.com"
    receiver_email = "mwang283@usc.edu"
    password = "pestai666"

    msg = """\
    Subject: [Alert] New Spot Alert!

{}
    """.format(message)

    context = ssl.create_default_context()
    with smtplib.SMTP(smtp_server, port) as server:
        server.ehlo()  # Can be omitted
        server.starttls(context=context)
        server.ehlo()  # Can be omitted
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, msg)

# %%
notifiy("Ming Wang is soooooo coooooooool!")
